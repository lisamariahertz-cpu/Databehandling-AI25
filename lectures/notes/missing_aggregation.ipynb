# %% [markdown]
# ## Pandas: Data Manipulation & Handling Missing Data
#
# In this lesson, we'll cover foundational techniques in Pandas for data manipulation, incluing creating and modifying DataFrames, handling missing data, and grouping data for aggregation. We'll also dive deeper into strategies for handling missing data.

# %% [markdown]
# ---

# %%
import numpy as np
import pandas as pd

import random

# %% [markdown]
# **Let's create a DataFrame of random data**

# %%
data_dict = {f'column {i}': [random.randint(0, 100) for _ in range(10)]  for i in range(10)}

data_dict
# Out:
# {'column 0': [56, 55, 39, 86, 53, 57, 38, 21, 10, 86],
#  'column 1': [91, 5, 93, 0, 24, 18, 40, 38, 93, 91],
#  'column 2': [10, 68, 72, 62, 50, 17, 62, 31, 21, 85],
#  'column 3': [32, 19, 71, 14, 48, 14, 10, 45, 58, 78],
#  'column 4': [99, 14, 28, 52, 65, 70, 40, 84, 99, 61],
#  'column 5': [85, 16, 84, 55, 9, 48, 69, 5, 17, 67],
#  'column 6': [87, 29, 31, 93, 32, 80, 62, 24, 54, 31],
#  'column 7': [45, 47, 99, 29, 61, 15, 96, 97, 20, 23],
#  'column 8': [20, 77, 0, 55, 73, 89, 40, 89, 49, 86],
#  'column 9': [74, 60, 93, 78, 0, 10, 19, 77, 58, 72]}

# %%
data_df = pd.DataFrame(data_dict)

data_df
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0        56        91        10        32        99        85        87
# 1        55         5        68        19        14        16        29
# 2        39        93        72        71        28        84        31
# 3        86         0        62        14        52        55        93
# 4        53        24        50        48        65         9        32
# 5        57        18        17        14        70        48        80
# 6        38        40        62        10        40        69        62
# 7        21        38        31        45        84         5        24
# 8        10        93        21        58        99        17        54
# 9        86        91        85        78        61        67        31
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3        29        55        78
# 4        61        73         0
# 5        15        89        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9        23        86        72

# %% [markdown]
# ## Modify data in a DataFrame

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column 0  10 non-null     int64
#  1   column 1  10 non-null     int64
#  2   column 2  10 non-null     int64
#  3   column 3  10 non-null     int64
#  4   column 4  10 non-null     int64
#  5   column 5  10 non-null     int64
#  6   column 6  10 non-null     int64
#  7   column 7  10 non-null     int64
#  8   column 8  10 non-null     int64
#  9   column 9  10 non-null     int64
# dtypes: int64(10)
# memory usage: 932.0 bytes

# %%
data_df.iloc[3, 5] = 180

data_df
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0        56        91        10        32        99        85        87
# 1        55         5        68        19        14        16        29
# 2        39        93        72        71        28        84        31
# 3        86         0        62        14        52       180        93
# 4        53        24        50        48        65         9        32
# 5        57        18        17        14        70        48        80
# 6        38        40        62        10        40        69        62
# 7        21        38        31        45        84         5        24
# 8        10        93        21        58        99        17        54
# 9        86        91        85        78        61        67        31
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3        29        55        78
# 4        61        73         0
# 5        15        89        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9        23        86        72

# %%
data_df.loc[7, 'column 2'] = -220

data_df
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0        56        91        10        32        99        85        87
# 1        55         5        68        19        14        16        29
# 2        39        93        72        71        28        84        31
# 3        86         0        62        14        52       180        93
# 4        53        24        50        48        65         9        32
# 5        57        18        17        14        70        48        80
# 6        38        40        62        10        40        69        62
# 7        21        38      -220        45        84         5        24
# 8        10        93        21        58        99        17        54
# 9        86        91        85        78        61        67        31
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3        29        55        78
# 4        61        73         0
# 5        15        89        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9        23        86        72

# %%
# changing multiple values at once

data_df.iloc[:3, :3] = 0

data_df
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0         0         0         0        32        99        85        87
# 1         0         0         0        19        14        16        29
# 2         0         0         0        71        28        84        31
# 3        86         0        62        14        52       180        93
# 4        53        24        50        48        65         9        32
# 5        57        18        17        14        70        48        80
# 6        38        40        62        10        40        69        62
# 7        21        38      -220        45        84         5        24
# 8        10        93        21        58        99        17        54
# 9        86        91        85        78        61        67        31
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3        29        55        78
# 4        61        73         0
# 5        15        89        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9        23        86        72

# %% [markdown]
# **Using iloc and loc to modify values based on conditions**

# %%
(data_df['column 0'] > 50).values
# Out:
# array([False, False, False,  True,  True,  True, False, False, False,
#         True])

# %%
data_df.iloc[(data_df['column 0'] > 50).values, [7,8]]
# Out:
#    column 7  column 8
# 3        29        55
# 4        61        73
# 5        15        89
# 9        23        86

# %%
data_df.iloc[data_df['column 0'] > 50, [7, 8]] = -9999

# %%
data_df
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0         0         0         0        32        99        85        87
# 1         0         0         0        19        14        16        29
# 2         0         0         0        71        28        84        31
# 3        86         0        62        14        52       180        93
# 4        53        24        50        48        65         9        32
# 5        57        18        17        14        70        48        80
# 6        38        40        62        10        40        69        62
# 7        21        38      -220        45        84         5        24
# 8        10        93        21        58        99        17        54
# 9        86        91        85        78        61        67        31
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3     -9999     -9999        78
# 4     -9999     -9999         0
# 5     -9999     -9999        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9     -9999     -9999        72

# %%
data_df.loc[data_df['column 1'] > 80, ['column 4', 'column 6']]
# Out:
#    column 4  column 6
# 8        99        54
# 9        61        31

# %%
data_df.loc[data_df['column 1'] > 80, ['column 4', 'column 6']] = 123456789

data_df
# Out:
#    column 0  column 1  column 2  column 3   column 4  column 5   column 6  \
# 0         0         0         0        32         99        85         87
# 1         0         0         0        19         14        16         29
# 2         0         0         0        71         28        84         31
# 3        86         0        62        14         52       180         93
# 4        53        24        50        48         65         9         32
# 5        57        18        17        14         70        48         80
# 6        38        40        62        10         40        69         62
# 7        21        38      -220        45         84         5         24
# 8        10        93        21        58  123456789        17  123456789
# 9        86        91        85        78  123456789        67  123456789
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3     -9999     -9999        78
# 4     -9999     -9999         0
# 5     -9999     -9999        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9     -9999     -9999        72

# %% [markdown]
# ---

# %% [markdown]
# ## Handling missing data in Pandas

# %%
data_df
# Out:
#    column 0  column 1  column 2  column 3   column 4  column 5   column 6  \
# 0         0         0         0        32         99        85         87
# 1         0         0         0        19         14        16         29
# 2         0         0         0        71         28        84         31
# 3        86         0        62        14         52       180         93
# 4        53        24        50        48         65         9         32
# 5        57        18        17        14         70        48         80
# 6        38        40        62        10         40        69         62
# 7        21        38      -220        45         84         5         24
# 8        10        93        21        58  123456789        17  123456789
# 9        86        91        85        78  123456789        67  123456789
#
#    column 7  column 8  column 9
# 0        45        20        74
# 1        47        77        60
# 2        99         0        93
# 3     -9999     -9999        78
# 4     -9999     -9999         0
# 5     -9999     -9999        10
# 6        96        40        19
# 7        97        89        77
# 8        20        49        58
# 9     -9999     -9999        72

# %%
data_df.loc[2, 'column 6'] = None
data_df.loc[8, 'column 6'] = None
data_df.loc[4, 'column 7'] = None

data_df
# Out:
#    column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0         0         0         0        32         99        85         87.0
# 1         0         0         0        19         14        16         29.0
# 2         0         0         0        71         28        84          NaN
# 3        86         0        62        14         52       180         93.0
# 4        53        24        50        48         65         9         32.0
# 5        57        18        17        14         70        48         80.0
# 6        38        40        62        10         40        69         62.0
# 7        21        38      -220        45         84         5         24.0
# 8        10        93        21        58  123456789        17          NaN
# 9        86        91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 2      99.0         0        93
# 3   -9999.0     -9999        78
# 4       NaN     -9999         0
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 8      20.0        49        58
# 9   -9999.0     -9999        72

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column 0  10 non-null     int64
#  1   column 1  10 non-null     int64
#  2   column 2  10 non-null     int64
#  3   column 3  10 non-null     int64
#  4   column 4  10 non-null     int64
#  5   column 5  10 non-null     int64
#  6   column 6  8 non-null      float64
#  7   column 7  9 non-null      float64
#  8   column 8  10 non-null     int64
#  9   column 9  10 non-null     int64
# dtypes: float64(2), int64(8)
# memory usage: 932.0 bytes

# %%
data_df.isnull()

# data_df.isna()
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0     False     False     False     False     False     False     False
# 1     False     False     False     False     False     False     False
# 2     False     False     False     False     False     False      True
# 3     False     False     False     False     False     False     False
# 4     False     False     False     False     False     False     False
# 5     False     False     False     False     False     False     False
# 6     False     False     False     False     False     False     False
# 7     False     False     False     False     False     False     False
# 8     False     False     False     False     False     False      True
# 9     False     False     False     False     False     False     False
#
#    column 7  column 8  column 9
# 0     False     False     False
# 1     False     False     False
# 2     False     False     False
# 3     False     False     False
# 4      True     False     False
# 5     False     False     False
# 6     False     False     False
# 7     False     False     False
# 8     False     False     False
# 9     False     False     False

# %%
data_df.isnull().sum()

#data_df.isnull().sum(axis=1)  # kommer summera över rader istället
# Out:
# column 0    0
# column 1    0
# column 2    0
# column 3    0
# column 4    0
# column 5    0
# column 6    2
# column 7    1
# column 8    0
# column 9    0
# dtype: int64

# %%
data_df.isnull().sum().sum()
# Out:
# np.int64(3)

# %%
data_df.notnull()

# är helt ekvivalent med
# ~data_df.isnull()
# Out:
#    column 0  column 1  column 2  column 3  column 4  column 5  column 6  \
# 0      True      True      True      True      True      True      True
# 1      True      True      True      True      True      True      True
# 2      True      True      True      True      True      True     False
# 3      True      True      True      True      True      True      True
# 4      True      True      True      True      True      True      True
# 5      True      True      True      True      True      True      True
# 6      True      True      True      True      True      True      True
# 7      True      True      True      True      True      True      True
# 8      True      True      True      True      True      True     False
# 9      True      True      True      True      True      True      True
#
#    column 7  column 8  column 9
# 0      True      True      True
# 1      True      True      True
# 2      True      True      True
# 3      True      True      True
# 4     False      True      True
# 5      True      True      True
# 6      True      True      True
# 7      True      True      True
# 8      True      True      True
# 9      True      True      True

# %% [markdown]
# Note that sometimes we might have dirty data in our dataset that is not counted as missing data, but is still important for you to identify and remedy, for example empty strings MIGHT be dirty and not intended data.

# %%
data_df
# Out:
#    column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0         0         0         0        32         99        85         87.0
# 1         0         0         0        19         14        16         29.0
# 2         0         0         0        71         28        84          NaN
# 3        86         0        62        14         52       180         93.0
# 4        53        24        50        48         65         9         32.0
# 5        57        18        17        14         70        48         80.0
# 6        38        40        62        10         40        69         62.0
# 7        21        38      -220        45         84         5         24.0
# 8        10        93        21        58  123456789        17          NaN
# 9        86        91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 2      99.0         0        93
# 3   -9999.0     -9999        78
# 4       NaN     -9999         0
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 8      20.0        49        58
# 9   -9999.0     -9999        72

# %%
data_df.iloc[9, 0] = ''

data_df
# Out:
# C:\Users\Lisa\AppData\Local\Temp\ipykernel_14484\1036150547.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with int64, please explicitly cast to a compatible dtype first.
#   data_df.iloc[9, 0] = ''
#   column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0        0         0         0        32         99        85         87.0
# 1        0         0         0        19         14        16         29.0
# 2        0         0         0        71         28        84          NaN
# 3       86         0        62        14         52       180         93.0
# 4       53        24        50        48         65         9         32.0
# 5       57        18        17        14         70        48         80.0
# 6       38        40        62        10         40        69         62.0
# 7       21        38      -220        45         84         5         24.0
# 8       10        93        21        58  123456789        17          NaN
# 9                 91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 2      99.0         0        93
# 3   -9999.0     -9999        78
# 4       NaN     -9999         0
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 8      20.0        49        58
# 9   -9999.0     -9999        72

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   column 0  10 non-null     object
#  1   column 1  10 non-null     int64
#  2   column 2  10 non-null     int64
#  3   column 3  10 non-null     int64
#  4   column 4  10 non-null     int64
#  5   column 5  10 non-null     int64
#  6   column 6  8 non-null      float64
#  7   column 7  9 non-null      float64
#  8   column 8  10 non-null     int64
#  9   column 9  10 non-null     int64
# dtypes: float64(2), int64(7), object(1)
# memory usage: 932.0+ bytes

# %% [markdown]
# ---

# %% [markdown]
# ## Strategies for handling missing data
#
# In some cases, especially when the amount of missing data is minimal or "irrelevant", it's acceptable to simply remove rows or columns that contain missing values. This approach can be useful if you have a lot of data and don't need all the information.

# %%
# by default, drops ALL rows containing atleast one missing value

data_df.dropna()
# Out:
#   column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0        0         0         0        32         99        85         87.0
# 1        0         0         0        19         14        16         29.0
# 3       86         0        62        14         52       180         93.0
# 5       57        18        17        14         70        48         80.0
# 6       38        40        62        10         40        69         62.0
# 7       21        38      -220        45         84         5         24.0
# 9                 91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 3   -9999.0     -9999        78
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 9   -9999.0     -9999        72

# %%
# we can also instead drop all COLUMNS by providing axis=1 to dropna()

data_df.dropna(axis=1)
# Out:
#   column 0  column 1  column 2  column 3   column 4  column 5  column 8  \
# 0        0         0         0        32         99        85        20
# 1        0         0         0        19         14        16        77
# 2        0         0         0        71         28        84         0
# 3       86         0        62        14         52       180     -9999
# 4       53        24        50        48         65         9     -9999
# 5       57        18        17        14         70        48     -9999
# 6       38        40        62        10         40        69        40
# 7       21        38      -220        45         84         5        89
# 8       10        93        21        58  123456789        17        49
# 9                 91        85        78  123456789        67     -9999
#
#    column 9
# 0        74
# 1        60
# 2        93
# 3        78
# 4         0
# 5        10
# 6        19
# 7        77
# 8        58
# 9        72

# %%
# data_df.dropna(inplace=True)   # inplace can be used to permanently delete the rows (or columns) containing missing values

# %% [markdown]
# ---

# %% [markdown]
# ## Strategy 2: filling missing data (imputation)
#
# In other cases, it's more appropriate to fill the missing data with a certain value. This can be done using the **fillna()** method

# %% [markdown]
# **Filling in with a constant value**

# %%
data_df
# Out:
#   column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0        0         0         0        32         99        85         87.0
# 1        0         0         0        19         14        16         29.0
# 2        0         0         0        71         28        84          NaN
# 3       86         0        62        14         52       180         93.0
# 4       53        24        50        48         65         9         32.0
# 5       57        18        17        14         70        48         80.0
# 6       38        40        62        10         40        69         62.0
# 7       21        38      -220        45         84         5         24.0
# 8       10        93        21        58  123456789        17          NaN
# 9                 91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 2      99.0         0        93
# 3   -9999.0     -9999        78
# 4       NaN     -9999         0
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 8      20.0        49        58
# 9   -9999.0     -9999        72

# %%
data_df.fillna(666)  # imputes 666 for missing values, WHEREVER they are in the dataset
# Out:
#   column 0  column 1  column 2  column 3   column 4  column 5     column 6  \
# 0        0         0         0        32         99        85         87.0
# 1        0         0         0        19         14        16         29.0
# 2        0         0         0        71         28        84        666.0
# 3       86         0        62        14         52       180         93.0
# 4       53        24        50        48         65         9         32.0
# 5       57        18        17        14         70        48         80.0
# 6       38        40        62        10         40        69         62.0
# 7       21        38      -220        45         84         5         24.0
# 8       10        93        21        58  123456789        17        666.0
# 9                 91        85        78  123456789        67  123456789.0
#
#    column 7  column 8  column 9
# 0      45.0        20        74
# 1      47.0        77        60
# 2      99.0         0        93
# 3   -9999.0     -9999        78
# 4     666.0     -9999         0
# 5   -9999.0     -9999        10
# 6      96.0        40        19
# 7      97.0        89        77
# 8      20.0        49        58
# 9   -9999.0     -9999        72

# %% [markdown]
# **Limit imputation to a certain column**

# %%
data_df['column 7'].fillna(54321)

# data_df['column 7'] = data_df['column 7'].fillna(54321)
# data_df['column 7'].fillna(54321, inplace=True)
# Out:
# 0       45.0
# 1       47.0
# 2       99.0
# 3    -9999.0
# 4    54321.0
# 5    -9999.0
# 6       96.0
# 7       97.0
# 8       20.0
# 9    -9999.0
# Name: column 7, dtype: float64

# %% [markdown]
# **Filling in with statistical values (mean, median, mode)**
#
# **mean**

# %%
data_df['column 7'].fillna(data_df['column 7'].mean())
# Out:
# 0      45.000000
# 1      47.000000
# 2      99.000000
# 3   -9999.000000
# 4   -3288.111111
# 5   -9999.000000
# 6      96.000000
# 7      97.000000
# 8      20.000000
# 9   -9999.000000
# Name: column 7, dtype: float64

# %% [markdown]
# **median**

# %%
data_df['column 7'].fillna(data_df['column 7'].median())
# Out:
# 0      45.0
# 1      47.0
# 2      99.0
# 3   -9999.0
# 4      45.0
# 5   -9999.0
# 6      96.0
# 7      97.0
# 8      20.0
# 9   -9999.0
# Name: column 7, dtype: float64

# %% [markdown]
# ---
#
# ## Groupding data with groupby

# %% [markdown]
# Groupding data allows us to perform aggregations on subsets of said data. For example, we might want to calculate the average value of a column for each unique value in another column.

# %%
import seaborn as sns

titanic_df = sns.load_dataset('titanic')

titanic_df.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
titanic_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   survived     891 non-null    int64
#  1   pclass       891 non-null    int64
#  2   sex          891 non-null    object
#  3   age          714 non-null    float64
#  4   sibsp        891 non-null    int64
#  5   parch        891 non-null    int64
#  6   fare         891 non-null    float64
#  7   embarked     889 non-null    object
#  8   class        891 non-null    category
#  9   who          891 non-null    object
#  10  adult_male   891 non-null    bool
#  11  deck         203 non-null    category
#  12  embark_town  889 non-null    object
#  13  alive        891 non-null    object
#  14  alone        891 non-null    bool
# dtypes: bool(2), category(2), float64(2), int64(4), object(5)
# memory usage: 80.7+ KB

# %%
titanic_df['who'].unique()
# Out:
# array(['man', 'woman', 'child'], dtype=object)

# %%
child_mask = titanic_df['who'] == 'child'
male_mask = titanic_df['sex'] == 'male'


titanic_df[child_mask & male_mask].head(10)
# Out:
#      survived  pclass   sex    age  sibsp  parch     fare embarked   class  \
# 7           0       3  male   2.00      3      1  21.0750        S   Third
# 16          0       3  male   2.00      4      1  29.1250        Q   Third
# 50          0       3  male   7.00      4      1  39.6875        S   Third
# 59          0       3  male  11.00      5      2  46.9000        S   Third
# 63          0       3  male   4.00      3      2  27.9000        S   Third
# 78          1       2  male   0.83      0      2  29.0000        S  Second
# 125         1       3  male  12.00      1      0  11.2417        C   Third
# 164         0       3  male   1.00      4      1  39.6875        S   Third
# 165         1       3  male   9.00      0      2  20.5250        S   Third
# 171         0       3  male   4.00      4      1  29.1250        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 7    child       False  NaN  Southampton    no  False
# 16   child       False  NaN   Queenstown    no  False
# 50   child       False  NaN  Southampton    no  False
# 59   child       False  NaN  Southampton    no  False
# 63   child       False  NaN  Southampton    no  False
# 78   child       False  NaN  Southampton   yes  False
# 125  child       False  NaN    Cherbourg   yes  False
# 164  child       False  NaN  Southampton    no  False
# 165  child       False  NaN  Southampton   yes  False
# 171  child       False  NaN   Queenstown    no  False

# %%
titanic_df['survived'].value_counts()
# Out:
# survived
# 0    549
# 1    342
# Name: count, dtype: int64

# %%
# total average age

titanic_df['age'].mean()
# Out:
# np.float64(29.69911764705882)

# %%
sns.histplot(data=titanic_df, x='age', hue='sex')
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
titanic_df.groupby('sex')['age'].mean()
# Out:
# sex
# female    27.915709
# male      30.726645
# Name: age, dtype: float64

# %%
titanic_df.groupby('who')['age'].mean()
# Out:
# who
# child     6.369518
# man      33.173123
# woman    32.000000
# Name: age, dtype: float64

# %%
titanic_df.groupby('sex')['survived'].sum()
# Out:
# sex
# female    233
# male      109
# Name: survived, dtype: int64

# %%
titanic_df['class'].value_counts()
# Out:
# class
# Third     491
# First     216
# Second    184
# Name: count, dtype: int64

# %%
titanic_df.groupby('class')['survived'].sum()
# Out:
# C:\Users\Lisa\AppData\Local\Temp\ipykernel_14484\3919713658.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_df.groupby('class')['survived'].sum()
# class
# First     136
# Second     87
# Third     119
# Name: survived, dtype: int64

# %% [markdown]
# **Grouping by and aggregating by multiple columns**

# %%
titanic_df.groupby(['sex', 'survived'])['age'].mean()
# Out:
# sex     survived
# female  0           25.046875
#         1           28.847716
# male    0           31.618056
#         1           27.276022
# Name: age, dtype: float64

# %%
titanic_df.groupby(['sex', 'survived'])[['age', 'fare']].mean()
# Out:
#                        age       fare
# sex    survived
# female 0         25.046875  23.024385
#        1         28.847716  51.938573
# male   0         31.618056  21.960993
#        1         27.276022  40.821484

# %%
titanic_df.groupby(['sex', 'class', 'survived'])[['age', 'fare']].mean()
# Out:
# C:\Users\Lisa\AppData\Local\Temp\ipykernel_14484\4115897755.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   titanic_df.groupby(['sex', 'class', 'survived'])[['age', 'fare']].mean()
#                               age        fare
# sex    class  survived
# female First  0         25.666667  110.604167
#               1         34.939024  105.978159
#        Second 0         36.000000   18.250000
#               1         28.080882   22.288989
#        Third  0         23.818182   19.773093
#               1         19.329787   12.464526
# male   First  0         44.581967   62.894910
#               1         36.248000   74.637320
#        Second 0         33.369048   19.488965
#               1         16.022000   21.095100
#        Third  0         27.255814   12.204469
#               1         22.274211   15.579696

# %%
titanic_df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# 0      man        True  NaN  Southampton    no  False
# 1    woman       False    C    Cherbourg   yes  False
# 2    woman       False  NaN  Southampton   yes   True
# 3    woman       False    C  Southampton   yes  False
# 4      man        True  NaN  Southampton    no   True
# ..     ...         ...  ...          ...   ...    ...
# 886    man        True  NaN  Southampton    no   True
# 887  woman       False    B  Southampton   yes   True
# 888  woman       False  NaN  Southampton    no  False
# 889    man        True    C    Cherbourg   yes   True
# 890    man        True  NaN   Queenstown    no   True
#
# [891 rows x 15 columns]
